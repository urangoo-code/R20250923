# %%
# Tkinter Label: setup border width and border type
from tkinter import *
root = Tk()
font = ('Tahoma', 12) 
padx, pady = 10, 10
bg = 'LightGreen'
label1 = Label(root, text = 'Hello', bg = bg, bd = 2, relief = 'solid', font = font)
label1. pack ()
label2 = Label (root, text = 'Python', bd = 5, relief = 'sunken', bg = bg, font = font, padx = padx, pady = pady)
labe12. pack (padx = padx, pady = pady)
labe13 = Label(root, text = 'Tkinter', bd = 5, relief = 'raised',
               bg = bg, font = font, padx = padx, pady = pady)
labe13. pack (padx = padx, pady = pady)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 label1. pack ()
#       9 label2 = Label (root, text = 'Python', bd = 5, relief = 'sunken', bg = bg, font = font, padx = padx, pady = pady)
# ---> 10 labe12. pack (padx = padx, pady = pady)
#      11 labe13 = Label(root, text = 'Tkinter', bd = 5, relief = 'raised',
#      12                bg = bg, font = font, padx = padx, pady = pady)
#      13 labe13. pack (padx = padx, pady = pady)
#
# NameError: name 'labe12' is not defined

# %%
Hello
Python
# Tkinter Label: setup border width and border type
from tkinter import *
Tkinter
root = Tk()
font = ('Tahoma", 12)
Label
padx, pady = 10, 10
bg = 'LightGreen'
Windows Programming
labe14 = Label(root, text = 'Label', bd = 5, relief = 'groove',
bg = bg, font = font, padx = padx, pady = pady)
labe14. pack (padx = padx, pady = pady)
labe15 = Label(root, text = 'Windows Programming'
(bd = 5, relief = 'groove',
bg = bg, font = font, padx = padx, pady = pady)
labe15. pack(padx = padx, pady = pady)
root.mainloop()

# %%
# Position text within a label widget
from tkinter import *
Hello
There
class MyLabelPosition (Tk):
def _init_(self):
super ().__init_()
self. title( 'Position Text within a label')
self.label = Label(self, text = 'Hello\nThere',
bd = 4, relief = 'groove',
font = 'Tahoma 24', width = 10,
height = 4,
anchor = NE)
self.label.pack()
if
_name
== "
_main_
":
root = MyLabelPosition)
root.mainloop()
Saurabh Chandrakar et al. Building ModemGUls with tkinter and Python

# %%
from tkinter import * class MyJustifyLabel (Tk):
def_init_ (self) :
super() •init_()
self. title( 'Jusify in label')
font = ('Tahoma', 12)
text = 'Hello\nTkinter Label\nThere'
bd, relief, width, pady = 2, 'solid', 12, 10
# default justify is CENTER
Label (self, text = text, bd = bd, relief = relief,
font = font, width = width). pack (pady=pady)

# %%
# justify is LEFT
Label (self, text = text, bd = bd, relief = relief,
font = font, width = width, justify = LEFT) -pack (pady=pady)
# justify is RIGHT
Label (self, text = text, bd = bd, relief = relief,
font = font, width = width, justify = RIGHT) -pack(pady=pady)
if
_name_
main_":
root = MyJustifyLabel ()
Jusity in label —
root. geometry('300x300')
Hello
root.mainloop()
Tkinter Label
There
Hello
Tkinter Label
There
Hello
Tkinter Label
There
30

# %%
v if
Anc..
口
Anchor NE and Justify Right
from tkinter import * Hello
Tkinter Label
class MyAnchorJustify(Tk):
There
def
_init_ (self):
super () •_init_()
self. title('Anchor and Jusify in label')
Hello
Tkinter Label
font = ('Tahoma', 12)
There
text = 'Hello\nTkinter Label\nThere'
bd, relief, w, h, pady = 2,
'solid', 15, 5, 10
Label (self, text = 'Anchor NE and Justify Right'). pack()
Label (self, text = text, bd = bd, relief = relief, font = font,
width = w,height = h, anchor = NE, justify = RIGHT) pack ()
Label (self, text = 'Anchor NE and Justify Left'). pack()
Label (self, text = text, bd = bd, relief = relief, font = font,
width = w,height = h, anchor = NE, justify = LEFT). pack()
_name_
==.
"_main_":
root = MyAnchorJustify()
root. geometry ('250x320' )
root .mainloop

# %%
# Access the options of a thinter label using key-value pair
from tkinter import * class MyAcessOption (Tk):
definit (self):
super()._ init ()
self. title('Access options of a tkinter label')
labell = Label(self, text = 'Tkinter Label',
bd = 2, bg = ' LightGreen', relief
= 'solid',
font = ('Arial', 14), width = 20, height = 4,
anchor = Nw, justify = LEFT)
labe11.pack(padx=15, pady=15)
options = label1["text"] + '\n'
options
+=
"_" * 30 + '\n'
options
+= f"bd = (label1['bd']}\n"
options
+= f"bg = {label1['bg']}\n"
Saurabh Chandrakar et.al., Building ModernGUls with tinter and Python

# %%
options += f"font = {label1[ 'font']}\n"
options += f"width = {label1[ 'width']} \n"
options += f"height = {label1[ 'height']}\n"
options += f"anchor = {label1[' anchor']} \n"
options += f"justify = {label1['justify']}\n"
label2 = Label(self, text = options,
bd = 2, bg = 'LightBlue', relief = 'solid',
font = ('Arial', 12), width = 20,
anchor = NW, justify = LEFT, padx=10)
label2. pack (padx=15, pady=15)

# %%
V
if
name
=="
main_
":
root = MyAcessOption ()
root.mainloop()

# %%
from tkinter import *
class MyAcessChangeOption (Tk):
def _init_(self):
super () •init_()
self.title('Access and Change options of a tkinter label')
labe11 = Label(self, text = 'Tkinter Label',
bd = 2, bg = 'LightGreen', relief = 'solid',
font = ('Arial', 14), width = 20, height = 4,
anchor = NW, justify = LEFT)
labe11.pack(padx=15, pady=15)
label1["bg"] = 'LightYellow"
Access and... -
label1["fg"] = 'Blue'
Tkinter Label

# %%
from tkinter import *
class MyAcessChangeOption (Tk):
def
_init_ (self) :
super ()._init_()
self. title( 'Displaying key values of a tkinter label')
labell = Label(self, text = 'Tinter Label'
bd = 2, bg = ' LightGreen', relief = 'solid'
font = ('Arial', 12), width = 20, height = 2)
labe11. pack(padx=15, pady=10)
options =
for option in labell. keys():
# get default values if not mentioned
options += f"(option}: , (label1[option]} \n"
label2 = Label(self, text = options, bd = 2, bg = ' LightBlue',
relief = 'solid', font = ('Arial', 11),
anchor = NW, justify = LEFT, padx=10)
label2. pack(padx=15, pady=10)
if
name
==
_main_
root = MyAcessChangeOption()
root. mainloop()
